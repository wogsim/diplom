# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../Data/raw_posts.csv', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47066 entries, 0 to 47065
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              47066 non-null  int64
#  1   date            47066 non-null  object
#  2   text            27686 non-null  object
#  3   views_count     47066 non-null  int64
#  4   forwards_count  47066 non-null  int64
#  5   replies_count   47066 non-null  int64
#  6   reactions       21722 non-null  object
#  7   company_name    47066 non-null  object
#  8   channel_handle  47066 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 3.2+ MB

# %%
df['channel_handle'].value_counts()
# Out:
# channel_handle
# Selectel                 6102
# Positive_Technologies    3899
# Softline                 3131
# ICL_Services             3081
# jetinfosystems           2476
# p7office_channel         2366
# ibs_ru                   2263
# T1Holding                2209
# croc_it                  1874
# timewebru                1866
# megafon_probusiness      1864
# itpsnews                 1751
# Cloud4Y                  1429
# cloudruprovider          1415
# datafort_live            1161
# simbirsoft_depthdev      1155
# comp_s                   1068
# t1cloudnews              1060
# xcom_integration         1004
# itg_techlab               995
# itecogroup                978
# itfbgroup                 694
# wone_it                   659
# vk_digital_tech           584
# bssys                     569
# OnlantaLife               554
# linx_cloud_DC             370
# dataru_ru                 313
# ferrumitg                 174
# MTSWebServices              2
# ...

# %%
df[df['text'].isna()]['channel_handle'].value_counts()
# Out:
# channel_handle
# Selectel                 4067
# p7office_channel         1480
# Positive_Technologies    1389
# ICL_Services             1281
# ibs_ru                   1000
# megafon_probusiness       928
# cloudruprovider           774
# croc_it                   733
# T1Holding                 727
# timewebru                 722
# jetinfosystems            710
# t1cloudnews               680
# datafort_live             589
# comp_s                    506
# simbirsoft_depthdev       504
# Cloud4Y                   495
# Softline                  462
# itg_techlab               413
# itfbgroup                 324
# itecogroup                294
# xcom_integration          255
# wone_it                   220
# vk_digital_tech           213
# OnlantaLife               197
# itpsnews                  127
# linx_cloud_DC              83
# ferrumitg                  79
# dataru_ru                  67
# bssys                      61
# Name: count, dtype: int64

# %%
df['text'].head(1)
# Out:
# 0    🧑‍🏫Среднее специальное и профессиональное обра...
# Name: text, dtype: object

# %%
df_train = pd.read_csv('../../Data/processed_posts_with_prompts_train.csv', sep=';')
df_train['reward'].hist()
df_train['reward'].describe()
# Out:
# count    23514.000000
# mean        -0.091093
# std          0.877884
# min         -2.245630
# 25%         -0.744366
# 50%         -0.313805
# 75%          0.357184
# max          3.000000
# Name: reward, dtype: float64

# %%
(df_train['reward'] > 0.4).sum()
# Out:
# np.int64(5577)

# %%
df_test = pd.read_csv('../../Data/processed_posts_with_prompts_test.csv', sep=';')
df_test['reward'].hist()
df_test['reward'].describe()
# Out:
# count    4150.000000
# mean        0.400854
# std         1.002722
# min        -2.054002
# 25%        -0.368094
# 50%         0.244682
# 75%         0.981440
# max         3.000000
# Name: reward, dtype: float64
